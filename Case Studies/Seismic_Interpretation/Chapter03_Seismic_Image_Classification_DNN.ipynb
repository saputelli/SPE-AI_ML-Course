# %% [markdown]
# Seismic Image Classification - Deep Neural Network
# ---------------------------------------------

# %% [markdown]
# ### Load required libraries

# %%
# Let's import the libraries required for the image classification
import os
import glob
RAND_SEED = 1234
import numpy as np
np.random.seed(RAND_SEED)
import tensorflow as tf
tf.random.set_seed(RAND_SEED)
import random
random.seed(RAND_SEED)
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data from files

# %%
IMG_DIM = 96
IMG_PER_CLASS = 500
TEST_SPLIT_FRAC = 0.1
TRAIN_SPLIT_FRAC = 0.9
BATCH_SIZE = 32
NUM_CLASSES = 3

data_dir = './data'
class_names = ['fault', 'salt', 'other']
file_list = []

for class_name in class_names:
    class_files = glob.glob(data_dir + os.path.sep + \
                            class_name + os.path.sep + '*.png')
    for f in class_files:
        file_list.append(f)

def get_class_label(file_path):
    # Split file path to get directory and file names.
    path_split = file_path.split(os.path.sep)
    # The second-last string contains name of the class directory;
    # Use it to create class label.
    return class_names.index(path_split[-2].strip())

def decode_image(img):
    # Convert the passed image to a uint8 tensor;
    # Using 1 channel, as the images are grayscale.
    img = tf.image.decode_png(img, channels=1)
    # Convert image to floats in the [0,1] range.
    img = tf.image.convert_image_dtype(img, tf.float32)
    # Resize the image to the predefined image size.
    return tf.image.resize(img, [IMG_DIM, IMG_DIM]).numpy()

def process_file_path(file_path):
    label = get_class_label(file_path)
    # Load data from the image file.
    img = tf.io.read_file(file_path)
    # Decode and convert image data to float32.
    img = decode_image(img)
    return img, label

images = []
labels = []
for f in file_list:
    img, label = process_file_path(f)
    images.append(img)
    labels.append(label)
    
images = np.array(images)
labels = np.array(labels)

# %% [markdown]
# ### Create training, validation, and test data sets

# %%
def split_datasets(images, labels):
    # Split data into train, validation, and test data sets.
    X_rest, X_test, y_rest, y_test = \
    train_test_split(images, labels, test_size=TEST_SPLIT_FRAC, 
                     random_state=RAND_SEED, stratify=labels)
    X_train, X_valid, y_train, y_valid = \
    train_test_split(X_rest, y_rest, train_size=TRAIN_SPLIT_FRAC, 
                     random_state=RAND_SEED, stratify=y_rest)
    return X_train, X_valid, X_test, y_train, y_valid, y_test
    
X_train, X_valid, X_test, y_train, y_valid, y_test = \
split_datasets(images, labels)

# Plot class population distribution in the training data
# Calculate population of three classes
population = [len(np.where(y_train == 0)[0]), 
              len(np.where(y_train == 1)[0]),
              len(np.where(y_train == 2)[0])]
# Plot
plt.bar(class_names, population)
plt.title('Population distribution: Training Data')

# determine the number of input features
n_features = IMG_DIM * IMG_DIM
n_train = population[0] + population[1] + population[2]
n_test = int(NUM_CLASSES * IMG_PER_CLASS * TEST_SPLIT_FRAC)
n_valid = NUM_CLASSES * IMG_PER_CLASS - n_train - n_test
X_train = np.reshape(X_train, (n_train, n_features))
X_valid = np.reshape(X_valid, (n_valid, n_features))
X_test = np.reshape(X_test, (n_test, n_features))

# %% [markdown]
# ### Visualize Training Images

# %%
def show_training_images(images, labels):
    plt.figure(figsize=(10,10))
    for i in range(20):
        ax = plt.subplot(4,5,i+1)
        plt.imshow(X_train[i].reshape((IMG_DIM, IMG_DIM)))
        plt.title(class_names[y_train[i]])
        plt.axis('off')

show_training_images(X_train, y_train)

# %% [markdown]
# ### Build and train a Deep Neural Network model

# %%
# Define a Deep Neural Network model
reg_param = 0.02 # Regularization parameter for L2 regularization
model = Sequential()
model.add(Dense(1024, activation='relu', kernel_initializer='he_normal', 
                kernel_regularizer=l2(reg_param), input_shape=(n_features,)))
model.add(Dense(512, activation='relu', kernel_initializer='he_normal', 
                kernel_regularizer=l2(reg_param)))
model.add(Dense(256, activation='relu', kernel_initializer='he_normal', 
                kernel_regularizer=l2(reg_param)))
model.add(Dense(128, activation='relu', kernel_initializer='he_normal', 
                kernel_regularizer=l2(reg_param)))
model.add(Dense(64, activation='relu', kernel_initializer='he_normal', 
                kernel_regularizer=l2(reg_param)))
model.add(Dense(32, activation='relu', kernel_initializer='he_normal', 
                kernel_regularizer=l2(reg_param)))
model.add(Dense(16, activation='relu', kernel_initializer='he_normal', 
                kernel_regularizer=l2(reg_param)))
model.add(Dense(8, activation='relu', kernel_initializer='he_normal', 
                kernel_regularizer=l2(reg_param)))
model.add(Dense(3, activation='softmax'))
# compile the model
model.compile(optimizer='Adadelta', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Early-stopping callback using validation
earlystop_callback = EarlyStopping(
    monitor='val_accuracy', min_delta=0.0001,
    patience=50)
# Save the best model
ckpt_path = './models/dnn.keras'
ckpt_callback = ModelCheckpoint(filepath=ckpt_path, mode='max', 
                                monitor='val_accuracy', verbose=1, 
                                save_best_only=True)
# Train the model
history = model.fit(X_train, y_train, epochs=500, batch_size=BATCH_SIZE, 
                    validation_data=(X_valid, y_valid), 
                    callbacks=[earlystop_callback, ckpt_callback], 
                    verbose=1)
# Out:
# Epoch 1/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.3373 - loss: 82.7427
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to ./models/dnn.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 181ms/step - accuracy: 0.3374 - loss: 82.7416 - val_accuracy: 0.3333 - val_loss: 82.6173
# Epoch 2/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3257 - loss: 82.5853
# Epoch 2: val_accuracy improved from 0.33333 to 0.34074, saving model to ./models/dnn.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - accuracy: 0.3261 - loss: 82.5844 - val_accuracy: 0.3407 - val_loss: 82.4766
# Epoch 3/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3349 - loss: 82.4441
# Epoch 3: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.3352 - loss: 82.4432 - val_accuracy: 0.3407 - val_loss: 82.3328
# Epoch 4/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3321 - loss: 82.2993
# Epoch 4: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.3323 - loss: 82.2984 - val_accuracy: 0.3185 - val_loss: 82.1868
# Epoch 5/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3377 - loss: 82.1527
# Epoch 5: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3378 - loss: 82.1518 - val_accuracy: 0.3259 - val_loss: 82.0402
# Epoch 6/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3363 - loss: 82.0048
# Epoch 6: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3364 - loss: 82.0039 - val_accuracy: 0.3185 - val_loss: 81.8924
# Epoch 7/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3402 - loss: 81.8565
# Epoch 7: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3404 - loss: 81.8556 - val_accuracy: 0.3333 - val_loss: 81.7432
# Epoch 8/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3472 - loss: 81.7077
# Epoch 8: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3473 - loss: 81.7068 - val_accuracy: 0.3333 - val_loss: 81.5942
# Epoch 9/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3484 - loss: 81.5589
# Epoch 9: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3485 - loss: 81.5580 - val_accuracy: 0.3333 - val_loss: 81.4451
# Epoch 10/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3492 - loss: 81.4103
# Epoch 10: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3494 - loss: 81.4094 - val_accuracy: 0.3333 - val_loss: 81.2958
# Epoch 11/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3508 - loss: 81.2615
# Epoch 11: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.3511 - loss: 81.2606 - val_accuracy: 0.3259 - val_loss: 81.1473
# Epoch 12/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.3518 - loss: 81.1129
# Epoch 12: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - accuracy: 0.3520 - loss: 81.1120 - val_accuracy: 0.3407 - val_loss: 80.9980
# Epoch 13/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.3539 - loss: 80.9640
# Epoch 13: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.3541 - loss: 80.9631 - val_accuracy: 0.3333 - val_loss: 80.8490
# Epoch 14/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3542 - loss: 80.8150
# Epoch 14: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.3544 - loss: 80.8141 - val_accuracy: 0.3185 - val_loss: 80.6999
# Epoch 15/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3499 - loss: 80.6654
# Epoch 15: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.3501 - loss: 80.6645 - val_accuracy: 0.3185 - val_loss: 80.5506
# Epoch 16/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3440 - loss: 80.5161
# Epoch 16: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.3442 - loss: 80.5152 - val_accuracy: 0.3185 - val_loss: 80.4011
# Epoch 17/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3483 - loss: 80.3666
# Epoch 17: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - accuracy: 0.3484 - loss: 80.3657 - val_accuracy: 0.3259 - val_loss: 80.2513
# Epoch 18/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.3502 - loss: 80.2171
# Epoch 18: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.3502 - loss: 80.2162 - val_accuracy: 0.3259 - val_loss: 80.1017
# Epoch 19/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3529 - loss: 80.0673
# Epoch 19: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.3530 - loss: 80.0664 - val_accuracy: 0.3333 - val_loss: 79.9520
# Epoch 20/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.3534 - loss: 79.9178
# Epoch 20: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.3535 - loss: 79.9169 - val_accuracy: 0.3407 - val_loss: 79.8023
# Epoch 21/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3522 - loss: 79.7680
# Epoch 21: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.3523 - loss: 79.7671 - val_accuracy: 0.3333 - val_loss: 79.6525
# Epoch 22/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.3490 - loss: 79.6181
# Epoch 22: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.3492 - loss: 79.6172 - val_accuracy: 0.3407 - val_loss: 79.5026
# Epoch 23/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3520 - loss: 79.4683
# Epoch 23: val_accuracy did not improve from 0.34074
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.3522 - loss: 79.4674 - val_accuracy: 0.3407 - val_loss: 79.3527
# Epoch 24/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3542 - loss: 79.3184
# Epoch 24: val_accuracy improved from 0.34074 to 0.34815, saving model to ./models/dnn.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - accuracy: 0.3544 - loss: 79.3175 - val_accuracy: 0.3481 - val_loss: 79.2028
# Epoch 25/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3522 - loss: 79.1684
# Epoch 25: val_accuracy did not improve from 0.34815
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.3524 - loss: 79.1675 - val_accuracy: 0.3481 - val_loss: 79.0525
# Epoch 26/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3496 - loss: 79.0182
# Epoch 26: val_accuracy improved from 0.34815 to 0.35556, saving model to ./models/dnn.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.3498 - loss: 79.0173 - val_accuracy: 0.3556 - val_loss: 78.9024
# Epoch 27/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3543 - loss: 78.8681
# Epoch 27: val_accuracy did not improve from 0.35556
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.3545 - loss: 78.8672 - val_accuracy: 0.3556 - val_loss: 78.7524
# Epoch 28/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3577 - loss: 78.7180
# Epoch 28: val_accuracy did not improve from 0.35556
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.3579 - loss: 78.7171 - val_accuracy: 0.3556 - val_loss: 78.6025
# Epoch 29/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3585 - loss: 78.5680
# Epoch 29: val_accuracy did not improve from 0.35556
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3585 - loss: 78.5671 - val_accuracy: 0.3556 - val_loss: 78.4527
# Epoch 30/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3567 - loss: 78.4180
# Epoch 30: val_accuracy improved from 0.35556 to 0.36296, saving model to ./models/dnn.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.3568 - loss: 78.4171 - val_accuracy: 0.3630 - val_loss: 78.3030
# Epoch 31/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3551 - loss: 78.2683
# Epoch 31: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3552 - loss: 78.2674 - val_accuracy: 0.3630 - val_loss: 78.1537
# Epoch 32/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3576 - loss: 78.1187
# Epoch 32: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.3577 - loss: 78.1178 - val_accuracy: 0.3556 - val_loss: 78.0043
# Epoch 33/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3544 - loss: 77.9695
# Epoch 33: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3545 - loss: 77.9686 - val_accuracy: 0.3630 - val_loss: 77.8549
# Epoch 34/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3590 - loss: 77.8202
# Epoch 34: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3591 - loss: 77.8193 - val_accuracy: 0.3630 - val_loss: 77.7059
# Epoch 35/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3552 - loss: 77.6709
# Epoch 35: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3553 - loss: 77.6700 - val_accuracy: 0.3556 - val_loss: 77.5568
# Epoch 36/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3472 - loss: 77.5218
# Epoch 36: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.3474 - loss: 77.5209 - val_accuracy: 0.3481 - val_loss: 77.4079
# Epoch 37/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.
500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3489 - loss: 73.9898
# Epoch 60: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3491 - loss: 73.9889 - val_accuracy: 0.3630 - val_loss: 73.8813
# Epoch 61/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3476 - loss: 73.8449
# Epoch 61: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3478 - loss: 73.8441 - val_accuracy: 0.3630 - val_loss: 73.7366
# Epoch 62/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3476 - loss: 73.7003
# Epoch 62: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3478 - loss: 73.6994 - val_accuracy: 0.3556 - val_loss: 73.5921
# Epoch 63/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3513 - loss: 73.5559
# Epoch 63: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3515 - loss: 73.5551 - val_accuracy: 0.3556 - val_loss: 73.4478
# Epoch 64/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3505 - loss: 73.4118
# Epoch 64: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3507 - loss: 73.4109 - val_accuracy: 0.3556 - val_loss: 73.3038
# Epoch 65/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3505 - loss: 73.2677
# Epoch 65: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3507 - loss: 73.2668 - val_accuracy: 0.3556 - val_loss: 73.1601
# Epoch 66/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3502 - loss: 73.1239
# Epoch 66: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3504 - loss: 73.1230 - val_accuracy: 0.3556 - val_loss: 73.0166
# Epoch 67/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3502 - loss: 72.9803
# Epoch 67: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3504 - loss: 72.9795 - val_accuracy: 0.3556 - val_loss: 72.8734
# Epoch 68/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3519 - loss: 72.8370
# Epoch 68: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3521 - loss: 72.8362 - val_accuracy: 0.3630 - val_loss: 72.7304
# Epoch 69/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3519 - loss: 72.6941
# Epoch 69: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.3521 - loss: 72.6933 - val_accuracy: 0.3630 - val_loss: 72.5877
# Epoch 70/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3519 - loss: 72.5514
# Epoch 70: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3521 - loss: 72.5506 - val_accuracy: 0.3630 - val_loss: 72.4455
# Epoch 71/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3519 - loss: 72.4090
# Epoch 71: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.3521 - loss: 72.4082 - val_accuracy: 0.3630 - val_loss: 72.3037
# Epoch 72/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3519 - loss: 72.2669
# Epoch 72: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3521 - loss: 72.2660 - val_accuracy: 0.3630 - val_loss: 72.1619
# Epoch 73/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3519 - loss: 72.1250
# Epoch 73: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3521 - loss: 72.1242 - val_accuracy: 0.3630 - val_loss: 72.0202
# Epoch 74/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3519 - loss: 71.9833
# Epoch 74: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3521 - loss: 71.9825 - val_accuracy: 0.3630 - val_loss: 71.8788
# Epoch 75/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3497 - loss: 71.8419
# Epoch 75: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3499 - loss: 71.8410 - val_accuracy: 0.3630 - val_loss: 71.7377
# Epoch 76/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3519 - loss: 71.7008
# Epoch 76: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3521 - loss: 71.6999 - val_accuracy: 0.3630 - val_loss: 71.5968
# Epoch 77/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3497 - loss: 71.5599
# Epoch 77: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3499 - loss: 71.5591 - val_accuracy: 0.3630 - val_loss: 71.4562
# Epoch 78/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3490 - loss: 71.4192
# Epoch 78: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3491 - loss: 71.4183 - val_accuracy: 0.3630 - val_loss: 71.3159
# Epoch 79/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3490 - loss: 71.2788
# Epoch 79: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3491 - loss: 71.2780 - val_accuracy: 0.3630 - val_loss: 71.1757
# Epoch 80/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3497 - loss: 71.1386
# Epoch 80: val_accuracy did not improve from 0.36296
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3498 - loss: 71.1378 - val_accuracy: 0.3630 - val_loss: 71.0356

# %% [markdown]
# ### Review the model training

# %%
# Plot learning curves
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('Sparse Cat.Cross-Entropy')
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend()
plt.show()

# %% [markdown]
# ### Use saved model to predict test data

# %%
# Evaluate the best model using test data
model = load_model(ckpt_path)
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)
# Out:
# Test Accuracy: 0.327
