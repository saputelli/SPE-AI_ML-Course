# %% [markdown]
# Seismic Image Classification - Convolutional Neural Network
# ---------------------------------------------

# %% [markdown]
# ### Load required libraries

# %%
# Let's import the libraries required for the image classification
import os
import glob
RAND_SEED = 12345
import numpy as np
np.random.seed(RAND_SEED)
import tensorflow as tf
tf.random.set_seed(RAND_SEED)
import random
random.seed(RAND_SEED)
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data from files

# %%
IMG_DIM = 96
IMG_PER_CLASS = 500
TEST_SPLIT_FRAC = 0.1
TRAIN_SPLIT_FRAC = 0.9
BATCH_SIZE = 32
NUM_CLASSES = 3

data_dir = './data'
class_names = ['fault', 'salt', 'other']
file_list = []

for class_name in class_names:
    class_files = glob.glob(data_dir + os.path.sep + \
                            class_name + os.path.sep + '*.png')
    for f in class_files:
        file_list.append(f)

def get_class_label(file_path):
    # Split file path to get directory and file names.
    path_split = file_path.split(os.path.sep)
    # The second-last string contains name of the class directory;
    # Use it to create class label.
    return class_names.index(path_split[-2].strip())

def decode_image(img):
    # Convert the passed image to a uint8 tensor;
    # Using 1 channel, as the images are grayscale.
    img = tf.image.decode_png(img, channels=1)
    # Convert image to floats in the [0,1] range.
    img = tf.image.convert_image_dtype(img, tf.float32)
    # Resize the image to the predefined image size.
    return tf.image.resize(img, [IMG_DIM, IMG_DIM]).numpy()

def process_file_path(file_path):
    label = get_class_label(file_path)
    # Load data from the image file.
    img = tf.io.read_file(file_path)
    # Decode and convert image data to float32.
    img = decode_image(img)
    return img, label

images = []
labels = []
for f in file_list:
    img, label = process_file_path(f)
    images.append(img)
    labels.append(label)
    
images = np.array(images)
labels = np.array(labels)

# %% [markdown]
# ### Create training, validation, and test data sets

# %%
def split_datasets(images, labels):
    # Split data into train, validation, and test data sets.
    X_rest, X_test, y_rest, y_test = \
    train_test_split(images, labels, test_size=TEST_SPLIT_FRAC, 
                     random_state=RAND_SEED, stratify=labels)
    X_train, X_valid, y_train, y_valid = \
    train_test_split(X_rest, y_rest, train_size=TRAIN_SPLIT_FRAC, 
                     random_state=RAND_SEED, stratify=y_rest)
    return X_train, X_valid, X_test, y_train, y_valid, y_test
    
X_train, X_valid, X_test, y_train, y_valid, y_test = \
split_datasets(images, labels)

# Plot class population distribution in the training data
# Calculate population of three classes
population = [len(np.where(y_train == 0)[0]), 
              len(np.where(y_train == 1)[0]),
              len(np.where(y_train == 2)[0])]
# Plot
plt.bar(class_names, population)
plt.title('Population distribution: Training Data')

# determine the number of input features
n_train = population[0] + population[1] + population[2]
n_test = int(NUM_CLASSES * IMG_PER_CLASS * TEST_SPLIT_FRAC)
n_valid = NUM_CLASSES * IMG_PER_CLASS - n_train - n_test
X_train = np.reshape(X_train, (n_train, IMG_DIM, IMG_DIM, 1))
X_valid = np.reshape(X_valid, (n_valid, IMG_DIM, IMG_DIM, 1))
X_test = np.reshape(X_test, (n_test, IMG_DIM, IMG_DIM, 1))

# %% [markdown]
# ### Visualize Training Images

# %%
def show_training_images(images, labels):
    plt.figure(figsize=(10,10))
    for i in range(20):
        ax = plt.subplot(4,5,i+1)
        plt.imshow(X_train[i].reshape(IMG_DIM, IMG_DIM))
        plt.title(class_names[y_train[i]])
        plt.axis('off')

show_training_images(X_train, y_train)

# %% [markdown]
# ### Build and train a Deep Neural Network model

# %%
# Define a Deep Neural Network model
model = Sequential()
model.add(Conv2D(96, (5, 5), activation='relu', 
                 input_shape=(IMG_DIM, IMG_DIM, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (5, 5), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='softmax'))

# compile the model
model.compile(optimizer='Adadelta', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Early-stopping callback using validation
earlystop_callback = EarlyStopping(
    monitor='val_accuracy', min_delta=0.0001,
    patience=50)
# Save the best model
ckpt_path = './models/lstm.keras'
ckpt_callback = ModelCheckpoint(filepath=ckpt_path, mode='max', 
                                monitor='val_accuracy', verbose=1, 
                                save_best_only=True)
# Train the model
history = model.fit(X_train, y_train, epochs=500, batch_size=BATCH_SIZE, 
                    validation_data=(X_valid, y_valid), 
                    callbacks=[earlystop_callback, ckpt_callback], 
                    verbose=1)
# Out:
# Epoch 1/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3559 - loss: 1.0980
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to ./models/lstm.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 18s 389ms/step - accuracy: 0.3554 - loss: 1.0980 - val_accuracy: 0.3333 - val_loss: 1.0989
# Epoch 2/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3559 - loss: 1.0971
# Epoch 2: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 15s 380ms/step - accuracy: 0.3554 - loss: 1.0971 - val_accuracy: 0.3333 - val_loss: 1.0983
# Epoch 3/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.3559 - loss: 1.0965
# Epoch 3: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 373ms/step - accuracy: 0.3554 - loss: 1.0965 - val_accuracy: 0.3333 - val_loss: 1.0978
# Epoch 4/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3559 - loss: 1.0960
# Epoch 4: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 15s 386ms/step - accuracy: 0.3554 - loss: 1.0961 - val_accuracy: 0.3333 - val_loss: 1.0975
# Epoch 5/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.3559 - loss: 1.0956
# Epoch 5: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 377ms/step - accuracy: 0.3554 - loss: 1.0957 - val_accuracy: 0.3333 - val_loss: 1.0971
# Epoch 6/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3559 - loss: 1.0952
# Epoch 6: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 379ms/step - accuracy: 0.3554 - loss: 1.0953 - val_accuracy: 0.3333 - val_loss: 1.0968
# Epoch 7/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.3559 - loss: 1.0949
# Epoch 7: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 17s 440ms/step - accuracy: 0.3554 - loss: 1.0949 - val_accuracy: 0.3333 - val_loss: 1.0964
# Epoch 8/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.3559 - loss: 1.0945
# Epoch 8: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 16s 431ms/step - accuracy: 0.3554 - loss: 1.0945 - val_accuracy: 0.3333 - val_loss: 1.0961
# Epoch 9/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.3559 - loss: 1.0942
# Epoch 9: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 358ms/step - accuracy: 0.3554 - loss: 1.0942 - val_accuracy: 0.3333 - val_loss: 1.0958
# Epoch 10/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3559 - loss: 1.0939
# Epoch 10: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 377ms/step - accuracy: 0.3554 - loss: 1.0939 - val_accuracy: 0.3333 - val_loss: 1.0955
# Epoch 11/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.3559 - loss: 1.0936
# Epoch 11: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 378ms/step - accuracy: 0.3554 - loss: 1.0936 - val_accuracy: 0.3333 - val_loss: 1.0952
# Epoch 12/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.3559 - loss: 1.0933
# Epoch 12: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 371ms/step - accuracy: 0.3554 - loss: 1.0933 - val_accuracy: 0.3333 - val_loss: 1.0949
# Epoch 13/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.3559 - loss: 1.0931
# Epoch 13: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 374ms/step - accuracy: 0.3554 - loss: 1.0931 - val_accuracy: 0.3333 - val_loss: 1.0947
# Epoch 14/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.3559 - loss: 1.0928
# Epoch 14: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 378ms/step - accuracy: 0.3554 - loss: 1.0929 - val_accuracy: 0.3333 - val_loss: 1.0944
# Epoch 15/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3559 - loss: 1.0926
# Epoch 15: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 15s
val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 896ms/step - accuracy: 0.3554 - loss: 1.0882 - val_accuracy: 0.3333 - val_loss: 1.0899
# Epoch 35/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3559 - loss: 1.0879
# Epoch 35: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.3554 - loss: 1.0879 - val_accuracy: 0.3333 - val_loss: 1.0897
# Epoch 36/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.3559 - loss: 1.0876
# Epoch 36: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 997ms/step - accuracy: 0.3554 - loss: 1.0877 - val_accuracy: 0.3333 - val_loss: 1.0894
# Epoch 37/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 895ms/step - accuracy: 0.3559 - loss: 1.0873
# Epoch 37: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 36s 937ms/step - accuracy: 0.3554 - loss: 1.0874 - val_accuracy: 0.3333 - val_loss: 1.0892
# Epoch 38/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3559 - loss: 1.0871
# Epoch 38: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.3554 - loss: 1.0871 - val_accuracy: 0.3333 - val_loss: 1.0889
# Epoch 39/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3559 - loss: 1.0868
# Epoch 39: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.3554 - loss: 1.0868 - val_accuracy: 0.3333 - val_loss: 1.0887
# Epoch 40/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3559 - loss: 1.0865
# Epoch 40: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.3554 - loss: 1.0866 - val_accuracy: 0.3333 - val_loss: 1.0884
# Epoch 41/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 996ms/step - accuracy: 0.3559 - loss: 1.0862
# Epoch 41: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.3554 - loss: 1.0863 - val_accuracy: 0.3333 - val_loss: 1.0882
# Epoch 42/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3559 - loss: 1.0860
# Epoch 42: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.3554 - loss: 1.0860 - val_accuracy: 0.3333 - val_loss: 1.0879
# Epoch 43/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.3559 - loss: 1.0857
# Epoch 43: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 23s 591ms/step - accuracy: 0.3554 - loss: 1.0857 - val_accuracy: 0.3333 - val_loss: 1.0876
# Epoch 44/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.3559 - loss: 1.0854
# Epoch 44: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 16s 421ms/step - accuracy: 0.3554 - loss: 1.0855 - val_accuracy: 0.3333 - val_loss: 1.0874
# Epoch 45/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.3559 - loss: 1.0851
# Epoch 45: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 17s 439ms/step - accuracy: 0.3554 - loss: 1.0852 - val_accuracy: 0.3333 - val_loss: 1.0871
# Epoch 46/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.3559 - loss: 1.0849
# Epoch 46: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 19s 509ms/step - accuracy: 0.3554 - loss: 1.0849 - val_accuracy: 0.3333 - val_loss: 1.0869
# Epoch 47/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.3559 - loss: 1.0846
# Epoch 47: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 18s 480ms/step - accuracy: 0.3554 - loss: 1.0846 - val_accuracy: 0.3333 - val_loss: 1.0866
# Epoch 48/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.3559 - loss: 1.0843
# Epoch 48: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 18s 465ms/step - accuracy: 0.3554 - loss: 1.0843 - val_accuracy: 0.3333 - val_loss: 1.0863
# Epoch 49/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.3559 - loss: 1.0840
# Epoch 49: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 17s 437ms/step - accuracy: 0.3554 - loss: 1.0841 - val_accuracy: 0.3333 - val_loss: 1.0860
# Epoch 50/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.3559 - loss: 1.0837
# Epoch 50: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 17s 448ms/step - accuracy: 0.3554 - loss: 1.0838 - val_accuracy: 0.3333 - val_loss: 1.0858
# Epoch 51/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.3559 - loss: 1.0834
# Epoch 51: val_accuracy did not improve from 0.33333
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 18s 463ms/step - accuracy: 0.3554 - loss: 1.0835 - val_accuracy: 0.3333 - val_loss: 1.0855

# %% [markdown]
# ### Review the model training

# %%
# Plot learning curves
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('Sparse Cat.Cross-Entropy')
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend()
plt.show()

# %% [markdown]
# ### Use saved model to predict test data

# %%
# Evaluate the best model using test data
model = load_model(ckpt_path)
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)
# Out:
# Test Accuracy: 0.333
